# %% [markdown]
# <a href="https://colab.research.google.com/github/saraal1/IT326_Project/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Goal:
# The main objective of this project is to analyze heart disease data to identify patterns and factors associated with heart disease. The project aims to build a classification model that can predict whether a patient is likely to have heart disease based on their medical and clinical characteristics.In addition, the project seeks to identify the most important features that contribute to heart disease prediction and compare the performance of different classification algorithms to determine the most effective model. This can help demonstrate how data mining techniques can support the early detection and prediction of heart disease.
#
#
# # Dataset Description:
# The dataset used in this project was obtained from Kaggle.com: https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction

# %% [markdown]
# The dataset contains 918 records and 12 attributes.
#
# The dataset contains the following data types:
# - Integer: Age, RestingBP, Cholesterol, FastingBS, MaxHR, HeartDisease
# - Float: Oldpeak
# - Categorical: Sex, ChestPainType, RestingECG, ExerciseAngina, ST_Slope
#
# The class attribute is HeartDisease.
# - Class 0: 410 records
# - Class 1: 508 records

# %%
import pandas as pd

# Load directly from your GitHub repository raw link
url = "https://raw.githubusercontent.com/saraal1/IT326_Project/main/Dataset/Raw_dataset.csv"
df = pd.read_csv(url)

# 1. Number of objects and attributes
print(f"Number of instances (rows): {df.shape[0]}")
print(f"Number of attributes (columns): {df.shape[1]}\n")

# 2. Attribute data types
print("=== Attribute Data Types ===")
print(df.dtypes)
print("\n" + "-" * 30 + "\n")

# 3. Class attribute counts
print("=== Class Attribute Distribution ===")
print(df["HeartDisease"].value_counts())
print("\n" + "-" * 30 + "\n")

# 4. Sample preview
print("=== Sample of Raw Dataset ===")
df.head()
# Out:
# Number of instances (rows): 918
# Number of attributes (columns): 12
#
# === Attribute Data Types ===
# Age                 int64
# Sex                object
# ChestPainType      object
# RestingBP           int64
# Cholesterol         int64
# FastingBS           int64
# RestingECG         object
# MaxHR               int64
# ExerciseAngina     object
# Oldpeak           float64
# ST_Slope           object
# HeartDisease        int64
# dtype: object
#
# ------------------------------
#
# === Class Attribute Distribution ===
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64
#
# ------------------------------
#
# === Sample of Raw Dataset ===
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0
